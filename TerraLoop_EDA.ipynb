# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/TerraLoop/blob/main/TerraLoop_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
import plotly.express as px
import random
from datetime import datetime, timedelta
import plotly.colors

# %%
df_events = pl.read_csv('tl_events_polars.csv')
df_users = pl.read_csv('tl_users_polars.csv')
df_listings = pl.read_csv('tl_listings_polars.csv')

# %%
df_events = df_events.with_columns(
    pl.col("user_id").str.strip_chars().str.to_uppercase()
)

df_users = df_users.with_columns(
    pl.col("user_id").str.strip_chars().str.to_uppercase()
)

# %%
df_events.head()
# Out:
# shape: (5, 6)
# ┌─────────┬───────────────┬────────────────────────────┬──────────┬────────────┬─────────────────┐
# │ user_id ┆ event_type    ┆ event_time                 ┆ platform ┆ session_id ┆ item_category   │
# │ ---     ┆ ---           ┆ ---                        ┆ ---      ┆ ---        ┆ ---             │
# │ str     ┆ str           ┆ str                        ┆ str      ┆ i64        ┆ str             │
# ╞═════════╪═══════════════╪════════════════════════════╪══════════╪════════════╪═════════════════╡
# │ TL-0429 ┆ start_listing ┆ 2026-01-26T14:00:00.000000 ┆ android  ┆ 130687     ┆ Battery         │
# │ TL-0233 ┆ start_listing ┆ 2026-02-05T23:00:00.000000 ┆ web      ┆ 331073     ┆ Small Appliance │
# │ TL-0086 ┆ search_item   ┆ 2026-02-03T19:00:00.000000 ┆ ios      ┆ 588636     ┆ Battery         │
# │ TL-0288 ┆ start_listing ┆ 2026-02-15T07:00:00.000000 ┆ ios      ┆ 694530     ┆ Battery         │
# │ TL-0104 ┆ start_listing ┆ 2026-01-21T07:00:00.000000 ┆ web      ┆ 849706     ┆ Battery         │
# └─────────┴───────────────┴────────────────────────────┴──────────┴────────────┴─────────────────┘

# %%
df_users.head()
# Out:
# shape: (5, 4)
# ┌─────────┬────────────────────────────┬───────────┬───────────────┐
# │ user_id ┆ signup_date                ┆ user_tier ┆ region        │
# │ ---     ┆ ---                        ┆ ---       ┆ ---           │
# │ str     ┆ str                        ┆ str       ┆ str           │
# ╞═════════╪════════════════════════════╪═══════════╪═══════════════╡
# │ TL0000  ┆ 2026-01-22T00:00:00.000000 ┆ Basic     ┆ Asia          │
# │ TL0001  ┆ 2026-01-13T00:00:00.000000 ┆ Basic     ┆ Asia          │
# │ TL0002  ┆ 2026-01-29T00:00:00.000000 ┆ Basic     ┆ Asia          │
# │ TL0003  ┆ 2026-01-09T00:00:00.000000 ┆ Eco-Ally  ┆ Asia          │
# │ TL0004  ┆ 2026-01-10T00:00:00.000000 ┆ Basic     ┆ North America │
# └─────────┴────────────────────────────┴───────────┴───────────────┘

# %%
df_listings.head()
# Out:
# shape: (5, 5)
# ┌────────────┬──────────┬──────────────────┬───────────┬────────────────────────────┐
# │ listing_id ┆ owner_id ┆ eco_score_impact ┆ status    ┆ created_at                 │
# │ ---        ┆ ---      ┆ ---              ┆ ---       ┆ ---                        │
# │ str        ┆ str      ┆ i64              ┆ str       ┆ str                        │
# ╞════════════╪══════════╪══════════════════╪═══════════╪════════════════════════════╡
# │ LST-00000  ┆ TL-0021  ┆ 32               ┆ cancelled ┆ 2026-01-26T00:00:00.000000 │
# │ LST-00001  ┆ TL-0489  ┆ 53               ┆ completed ┆ 2026-01-27T00:00:00.000000 │
# │ LST-00002  ┆ TL-0138  ┆ 18               ┆ completed ┆ 2026-01-06T00:00:00.000000 │
# │ LST-00003  ┆ TL-0277  ┆ 100              ┆ active    ┆ 2026-01-26T00:00:00.000000 │
# │ LST-00004  ┆ TL-0479  ┆ 37               ┆ cancelled ┆ 2026-01-27T00:00:00.000000 │
# └────────────┴──────────┴──────────────────┴───────────┴────────────────────────────┘

# %%
print("Listings IDs sample:", df_listings["owner_id"].head(5).to_list())
print("Users IDs sample:", df_users["user_id"].head(5).to_list())
# Out:
# Listings IDs sample: ['TL-0021', 'TL-0489', 'TL-0138', 'TL-0277', 'TL-0479']
# Users IDs sample: ['TL0000', 'TL0001', 'TL0002', 'TL0003', 'TL0004']

# %%
df_users = df_users.with_columns(pl.col("user_id").str.strip_chars().str.to_uppercase())
df_listings = df_listings.with_columns(pl.col("owner_id").str.strip_chars().str.to_uppercase())

# %%
df_users.head()
# Out:
# shape: (5, 4)
# ┌─────────┬────────────────────────────┬───────────┬───────────────┐
# │ user_id ┆ signup_date                ┆ user_tier ┆ region        │
# │ ---     ┆ ---                        ┆ ---       ┆ ---           │
# │ str     ┆ str                        ┆ str       ┆ str           │
# ╞═════════╪════════════════════════════╪═══════════╪═══════════════╡
# │ TL0000  ┆ 2026-01-22T00:00:00.000000 ┆ Basic     ┆ Asia          │
# │ TL0001  ┆ 2026-01-13T00:00:00.000000 ┆ Basic     ┆ Asia          │
# │ TL0002  ┆ 2026-01-29T00:00:00.000000 ┆ Basic     ┆ Asia          │
# │ TL0003  ┆ 2026-01-09T00:00:00.000000 ┆ Eco-Ally  ┆ Asia          │
# │ TL0004  ┆ 2026-01-10T00:00:00.000000 ┆ Basic     ┆ North America │
# └─────────┴────────────────────────────┴───────────┴───────────────┘

# %%
df_listings.head()
# Out:
# shape: (5, 5)
# ┌────────────┬──────────┬──────────────────┬───────────┬────────────────────────────┐
# │ listing_id ┆ owner_id ┆ eco_score_impact ┆ status    ┆ created_at                 │
# │ ---        ┆ ---      ┆ ---              ┆ ---       ┆ ---                        │
# │ str        ┆ str      ┆ i64              ┆ str       ┆ str                        │
# ╞════════════╪══════════╪══════════════════╪═══════════╪════════════════════════════╡
# │ LST-00000  ┆ TL-0021  ┆ 32               ┆ cancelled ┆ 2026-01-26T00:00:00.000000 │
# │ LST-00001  ┆ TL-0489  ┆ 53               ┆ completed ┆ 2026-01-27T00:00:00.000000 │
# │ LST-00002  ┆ TL-0138  ┆ 18               ┆ completed ┆ 2026-01-06T00:00:00.000000 │
# │ LST-00003  ┆ TL-0277  ┆ 100              ┆ active    ┆ 2026-01-26T00:00:00.000000 │
# │ LST-00004  ┆ TL-0479  ┆ 37               ┆ cancelled ┆ 2026-01-27T00:00:00.000000 │
# └────────────┴──────────┴──────────────────┴───────────┴────────────────────────────┘

# %%
# Forcing listings to only use valid user_ids
existing_ids = df_users['user_id'].to_list()

df_listings = df_listings.with_columns(
    pl.Series('owner_id',[random.choice(existing_ids) for _ in range(len(df_listings))])
)

# %% [markdown]
# # **Enriching the listings**
#
# - We want to know the Tier fo the person who created the listing

# %%
# Filter df_events for 'start_listing' events and select relevant columns
start_listing_details = df_events.filter(pl.col('event_type') == 'start_listing').select(
    'user_id',
    'event_time',
    'item_category'
)

# Join df_listings with start_listing_details to get item_category
# Assumes a listing's created_at matches an event_time for a start_listing event by the same user
df_listings_with_category = df_listings.join(
    start_listing_details,
    left_on=['owner_id', 'created_at'],
    right_on=['user_id', 'event_time'],
    how='left' # Use left join to keep all listings
)

# Then join with df_users to get user details (user_tier, region etc.)
df_listings_enriched = df_listings_with_category.join(
    df_users,
    left_on='owner_id',
    right_on='user_id',
    how='left'
)

# %%
df_listings_enriched.head()
# Out:
# shape: (5, 8)
# ┌────────────┬──────────┬────────────┬───────────┬────────────┬────────────┬───────────┬───────────┐
# │ listing_id ┆ owner_id ┆ eco_score_ ┆ status    ┆ created_at ┆ signup_dat ┆ user_tier ┆ region    │
# │ ---        ┆ ---      ┆ impact     ┆ ---       ┆ ---        ┆ e          ┆ ---       ┆ ---       │
# │ str        ┆ str      ┆ ---        ┆ str       ┆ str        ┆ ---        ┆ str       ┆ str       │
# │            ┆          ┆ i64        ┆           ┆            ┆ str        ┆           ┆           │
# ╞════════════╪══════════╪════════════╪═══════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ LST-00000  ┆ TL0275   ┆ 32         ┆ cancelled ┆ 2026-01-26 ┆ 2026-01-02 ┆ Basic     ┆ Asia      │
# │            ┆          ┆            ┆           ┆ T00:00:00. ┆ T00:00:00. ┆           ┆           │
# │            ┆          ┆            ┆           ┆ 000000     ┆ 000000     ┆           ┆           │
# │ LST-00001  ┆ TL0373   ┆ 53         ┆ completed ┆ 2026-01-27 ┆ 2026-01-08 ┆ Basic     ┆ North     │
# │            ┆          ┆            ┆           ┆ T00:00:00. ┆ T00:00:00. ┆           ┆ America   │
# │            ┆          ┆            ┆           ┆ 000000     ┆ 000000     ┆           ┆           │
# │ LST-00002  ┆ TL0432   ┆ 18         ┆ completed ┆ 2026-01-06 ┆ 2026-01-27 ┆ Basic     ┆ Europe    │
# │            ┆          ┆            ┆           ┆ T00:00:00. ┆ T00:00:00. ┆           ┆           │
# │            ┆          ┆            ┆           ┆ 000000     ┆ 000000     ┆           ┆           │
# │ LST-00003  ┆ TL0421   ┆ 100        ┆ active    ┆ 2026-01-26 ┆ 2026-01-24 ┆ Basic     ┆ Europe    │
# │            ┆          ┆            ┆           ┆ T00:00:00. ┆ T00:00:00. ┆           ┆           │
# │            ┆          ┆            ┆           ┆ 000000     ┆ 000000     ┆           ┆           │
# │ LST-00004  ┆ TL0018   ┆ 37         ┆ cancelled ┆ 2026-01-27 ┆ 2026-01-06 ┆ Basic     ┆ North     │
# │            ┆          ┆            ┆           ┆ T00:00:00. ┆ T00:00:00. ┆           ┆ America   │
# │            ┆          ┆            ┆           ┆ 000000     ┆ 000000     ┆           ┆           │
# └────────────┴──────────┴────────────┴───────────┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# # **Calculating Total Eco-Impract by Tier**

# %%
impact_summary = (
    df_listings_enriched.group_by('user_tier')
    .agg(
        pl.col('eco_score_impact').sum().alias('total_impact'),
        pl.col('listing_id').count().alias('listing_count')
    )
    .with_columns(
        (pl.col('total_impact') / pl.col('listing_count')).alias('avg_impact_per_listing')
    )
)

display(impact_summary)
# Out:
# shape: (3, 4)
# ┌───────────┬──────────────┬───────────────┬────────────────────────┐
# │ user_tier ┆ total_impact ┆ listing_count ┆ avg_impact_per_listing │
# │ ---       ┆ ---          ┆ ---           ┆ ---                    │
# │ str       ┆ i64          ┆ u32           ┆ f64                    │
# ╞═══════════╪══════════════╪═══════════════╪════════════════════════╡
# │ Basic     ┆ 28337        ┆ 518           ┆ 54.704633              │
# │ Eco-Ally  ┆ 11782        ┆ 224           ┆ 52.598214              │
# │ Premium   ┆ 3116         ┆ 58            ┆ 53.724138              │
# └───────────┴──────────────┴───────────────┴────────────────────────┘

# %% [markdown]
# # **Impact vs Volume**

# %%
fig1 = px.bar(
    impact_summary.to_pandas(),
    x='user_tier',
    y='total_impact',
    color='user_tier',
    text_auto='.2s',
    title='Total Eco-Score Impact by User Tier',
    labels={'total_impact':'Total Eco-Score Points','user_tier':'Membership Tier'}
)

fig1.update_layout(showlegend=False)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4dde5096-54dd-43da-a4d4-824f4076d481" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dde5096-54dd-43da-a4d4-824f4076d481")) {                    Plotly.newPlot(                        "4dde5096-54dd-43da-a4d4-824f4076d481",                        [{"alignmentgroup":"True","hovertemplate":"Membership Tier=%{x}\u003cbr\u003eTotal Eco-Score Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Basic","offsetgroup":"Basic","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Basic"],"xaxis":"x","y":[28337],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Membership Tier=%{x}\u003cbr\u003eTotal Eco-Score Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eco-Ally","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Eco-Ally","offsetgroup":"Eco-Ally","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Eco-Ally"],"xaxis":"x","y":[11782],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Membership Tier=%{x}\u003cbr\u003eTotal Eco-Score Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Premium","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Premium","offsetgroup":"Premium","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Premium"],"xaxis":"x","y":[3116],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f ...

# %% [markdown]
# # **Active Listing Density by Region**
#
# - Which geographics areas are most engaged with the circular economy ?

# %%
region_stats = (
    df_listings_enriched.group_by('region')
    .agg(
        pl.col('listing_id').count().alias('total_listings'),
        pl.col('owner_id').n_unique().alias('unique_sellers')
    )
    .with_columns(
        (pl.col('total_listings') / pl.col('unique_sellers')).alias('listings_per_user'),
        pl.col('total_listings').cast(pl.Float64)
    )
)

display(region_stats)
# Out:
# shape: (3, 4)
# ┌───────────────┬────────────────┬────────────────┬───────────────────┐
# │ region        ┆ total_listings ┆ unique_sellers ┆ listings_per_user │
# │ ---           ┆ ---            ┆ ---            ┆ ---               │
# │ str           ┆ f64            ┆ u32            ┆ f64               │
# ╞═══════════════╪════════════════╪════════════════╪═══════════════════╡
# │ North America ┆ 266.0          ┆ 133            ┆ 2.0               │
# │ Asia          ┆ 244.0          ┆ 130            ┆ 1.876923          │
# │ Europe        ┆ 290.0          ┆ 136            ┆ 2.132353          │
# └───────────────┴────────────────┴────────────────┴───────────────────┘

# %%
fig_reg = px.bar(
    region_stats.to_pandas(),
    x='region',
    y='listings_per_user',
    color='total_listings',
    title='Average Listings per Active User by Region',
    labels={'listings_per_user':'Listings Per User','region':'Region'},
    color_continuous_scale='Viridis'
)

fig_reg.update_layout(coloraxis_showscale=False)
fig_reg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="717703c3-d8c8-40c4-86c8-c5a02169ef41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("717703c3-d8c8-40c4-86c8-c5a02169ef41")) {                    Plotly.newPlot(                        "717703c3-d8c8-40c4-86c8-c5a02169ef41",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eListings Per User=%{y}\u003cbr\u003etotal_listings=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[266.0,244.0,290.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["North America","Asia","Europe"],"xaxis":"x","y":[2.0,1.876923076923077,2.1323529411764706],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10," ...

# %% [markdown]
# # **Eco-Impact by User Tier**
# - Tracking how much *'Green Value'* (Eco-Score) each tier generates over time.
# - This is our **North Star Metric**

# %%
# Preparing the time-series data
# Only convert if 'created_at' is not already a date type
if df_listings_enriched['created_at'].dtype != pl.Date:
    df_listings_enriched = df_listings_enriched.with_columns(
        pl.col('created_at').str.to_datetime("%Y-%m-%dT%H:%M:%S%.f").cast(pl.Date)
    )

display(df_listings_enriched.head())
# Out:
# shape: (5, 8)
# ┌────────────┬──────────┬────────────┬───────────┬────────────┬────────────┬───────────┬───────────┐
# │ listing_id ┆ owner_id ┆ eco_score_ ┆ status    ┆ created_at ┆ signup_dat ┆ user_tier ┆ region    │
# │ ---        ┆ ---      ┆ impact     ┆ ---       ┆ ---        ┆ e          ┆ ---       ┆ ---       │
# │ str        ┆ str      ┆ ---        ┆ str       ┆ date       ┆ ---        ┆ str       ┆ str       │
# │            ┆          ┆ i64        ┆           ┆            ┆ str        ┆           ┆           │
# ╞════════════╪══════════╪════════════╪═══════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ LST-00000  ┆ TL0275   ┆ 32         ┆ cancelled ┆ 2026-01-26 ┆ 2026-01-02 ┆ Basic     ┆ Asia      │
# │            ┆          ┆            ┆           ┆            ┆ T00:00:00. ┆           ┆           │
# │            ┆          ┆            ┆           ┆            ┆ 000000     ┆           ┆           │
# │ LST-00001  ┆ TL0373   ┆ 53         ┆ completed ┆ 2026-01-27 ┆ 2026-01-08 ┆ Basic     ┆ North     │
# │            ┆          ┆            ┆           ┆            ┆ T00:00:00. ┆           ┆ America   │
# │            ┆          ┆            ┆           ┆            ┆ 000000     ┆           ┆           │
# │ LST-00002  ┆ TL0432   ┆ 18         ┆ completed ┆ 2026-01-06 ┆ 2026-01-27 ┆ Basic     ┆ Europe    │
# │            ┆          ┆            ┆           ┆            ┆ T00:00:00. ┆           ┆           │
# │            ┆          ┆            ┆           ┆            ┆ 000000     ┆           ┆           │
# │ LST-00003  ┆ TL0421   ┆ 100        ┆ active    ┆ 2026-01-26 ┆ 2026-01-24 ┆ Basic     ┆ Europe    │
# │            ┆          ┆            ┆           ┆            ┆ T00:00:00. ┆           ┆           │
# │            ┆          ┆            ┆           ┆            ┆ 000000     ┆           ┆           │
# │ LST-00004  ┆ TL0018   ┆ 37         ┆ cancelled ┆ 2026-01-27 ┆ 2026-01-06 ┆ Basic     ┆ North     │
# │            ┆          ┆            ┆           ┆            ┆ T00:00:00. ┆           ┆ America   │
# │            ┆          ┆            ┆           ┆            ┆ 000000     ┆           ┆           │
# └────────────┴──────────┴────────────┴───────────┴────────────┴────────────┴───────────┴───────────┘

# %%
impact_over_time = (
    df_listings_enriched.group_by(['created_at','user_tier'])
    .agg(pl.col('eco_score_impact').sum().alias('daily_impact'))
    .sort('created_at')
    .with_columns(
        pl.col('daily_impact').cum_sum().over('user_tier').alias('total_impact')
    )
)

display(impact_over_time.head())
# Out:
# shape: (5, 4)
# ┌────────────┬───────────┬──────────────┬──────────────┐
# │ created_at ┆ user_tier ┆ daily_impact ┆ total_impact │
# │ ---        ┆ ---       ┆ ---          ┆ ---          │
# │ date       ┆ str       ┆ i64          ┆ i64          │
# ╞════════════╪═══════════╪══════════════╪══════════════╡
# │ 2026-01-01 ┆ Premium   ┆ 265          ┆ 265          │
# │ 2026-01-01 ┆ Eco-Ally  ┆ 582          ┆ 582          │
# │ 2026-01-01 ┆ Basic     ┆ 696          ┆ 696          │
# │ 2026-01-02 ┆ Eco-Ally  ┆ 118          ┆ 700          │
# │ 2026-01-02 ┆ Basic     ┆ 728          ┆ 1424         │
# └────────────┴───────────┴──────────────┴──────────────┘

# %%
fig_impact = px.line(
    impact_over_time.to_pandas(),
    x='created_at',
    y='total_impact',
    color='user_tier',
    title='Total Eco-Impact Growth over Time'
)

fig_impact.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5a99e42a-0cd2-4073-98bc-fcca55a66868" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a99e42a-0cd2-4073-98bc-fcca55a66868")) {                    Plotly.newPlot(                        "5a99e42a-0cd2-4073-98bc-fcca55a66868",                        [{"hovertemplate":"user_tier=Premium\u003cbr\u003ecreated_at=%{x}\u003cbr\u003etotal_impact=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Premium","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Premium","orientation":"v","showlegend":true,"x":["2026-01-01T00:00:00","2026-01-03T00:00:00","2026-01-04T00:00:00","2026-01-05T00:00:00","2026-01-06T00:00:00","2026-01-09T00:00:00","2026-01-10T00:00:00","2026-01-11T00:00:00","2026-01-12T00:00:00","2026-01-13T00:00:00","2026-01-14T00:00:00","2026-01-15T00:00:00","2026-01-16T00:00:00","2026-01-17T00:00:00","2026-01-19T00:00:00","2026-01-20T00:00:00","2026-01-21T00:00:00","2026-01-22T00:00:00","2026-01-24T00:00:00","2026-01-26T00:00:00","2026-01-27T00:00:00","2026-01-28T00:00:00","2026-01-29T00:00:00","2026-01-30T00:00:00","2026-01-31T00:00:00","2026-02-01T00:00:00","2026-02-02T00:00:00","2026-02-05T00:00:00","2026-02-08T00:00:00","2026-02-10T00:00:00"],"xaxis":"x","y":[265,310,492,533,583,654,664,713,770,850,897,931,951,1051,1171,1252,1504,1606,1758,1842,1861,1953,2213,2266,2332,2544,2793,2970,3089,3116],"yaxis":"y","type":"scatter"},{"hovertemplate":"user_tier=Eco-Ally\u003cbr\u003ecreated_at=%{x}\u003cbr\u003etotal_impact=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eco-Ally","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Eco-Ally","orientation":"v","showlegend":true,"x":["2026-01-01T00:00:00","2026-01-02T00:00:00","2026-01-03T00:00:00","2026-01-04T00:00:00","2026-01-05T00:00:00","2026-01-06T00:00:00","2026-01-07T00:00:00","2026-01-08T00:00:00","2026-01-09T00:00:00","2026-01-10T00:00:00","2026-01-11T00:00:00","2026-01-12T00:00:00","2026-01-13T00:00:00","2026-01-14T00:00:00","2026-01-15T00:00:00","2026-01-16T00:00:00","2026-01-17T00:00:00","2026-01-18T00:00:00","2026-01-19T00:00:00","2026-01-20T00:00:00","2026-01-21T00:00:00","2026-01-22T00:00:00","2026-01-23T00:00:00","2026-01-24T00:00:00","2026-01-25T00:00:00","2026-01-26T00:00:00","2026-01-27T00:00:00","2026-01-28T00:00:00","2026-01-29T00:00:00","2026-01-30T00:00:00","2026-01-31T00:00:00","2026-02-01T00:00:00","2026-02-02T00:00:00","2026-02-03T00:00:00","2026-02-04T00:00:00","2026-02-05T00:00:00","2026-02-06T00:00:00","2026-02-07T00:00:00","2026-02-08T00:00:00","2026-02-09T00:00:00","2026-02-10T00:00:00"],"xaxis":"x","y":[582,700,882,1334,1775,1896,2113,2369,2600,2792,2889,3168,3523,3805,4075,4494,5108,5404,5567,5667,6379,6726,7015,7378,7637,7910,8165,8329,8617,8745,8839,9212,9271,9734,10072,10474,10768,11002,11297,11622,11782],"yaxis":"y","type":"scatter"},{"hovertemplate":"user_tier=Basic\u003cbr\u003ecreated_at=%{x}\u003cbr\u003etotal_impact=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Basic","orientation":"v","showlegend":true,"x":["2026-01-01T00:00:00","2026-01-02T00:00:00","2026-01-03T00:00:00","2026-01-04T00:00:00","2026-01-05T00:00:00","2026-01-06T00:00:00","2026-01-07T00:00:00","2026-01-08T00:00:00","2026-01-09T00:00:00","2026-01-10T00:00:00","2026-01-11T00:00:00","2026-01-12T00:00:00","2026-01-13T00:00:00","2026-01-14T00:00:00","2026-01-15T00:00:00","2026-01-16T00:00:00","2026-01-17T00:00:00","2026-01-18T00:00:00","2026-01-19T00:00:00","2026-01-20T00:00:00","2026-01-21T00:00:00","2026-01-22T00:00:00","2026-01-23T00:00:00","2026-01-24T ...

# %%
impact_over_time = impact_over_time.with_columns(
    pl.col('daily_impact')
    .rolling_mean(window_size=7)
    .over('user_tier')
    .alias('rolling_avg_impact')
)

display(impact_over_time)
# Out:
# shape: (112, 5)
# ┌────────────┬───────────┬──────────────┬───────────────────┬────────────────────┐
# │ created_at ┆ user_tier ┆ daily_impact ┆ cumulative_impact ┆ rolling_avg_impact │
# │ ---        ┆ ---       ┆ ---          ┆ ---               ┆ ---                │
# │ date       ┆ str       ┆ i64          ┆ i64               ┆ f64                │
# ╞════════════╪═══════════╪══════════════╪═══════════════════╪════════════════════╡
# │ 2026-01-01 ┆ Basic     ┆ 696          ┆ 696               ┆ null               │
# │ 2026-01-01 ┆ Premium   ┆ 265          ┆ 265               ┆ null               │
# │ 2026-01-01 ┆ Eco-Ally  ┆ 582          ┆ 582               ┆ null               │
# │ 2026-01-02 ┆ Eco-Ally  ┆ 118          ┆ 700               ┆ null               │
# │ 2026-01-02 ┆ Basic     ┆ 728          ┆ 1424              ┆ null               │
# │ …          ┆ …         ┆ …            ┆ …                 ┆ …                  │
# │ 2026-02-09 ┆ Eco-Ally  ┆ 325          ┆ 11622             ┆ 335.857143         │
# │ 2026-02-09 ┆ Basic     ┆ 510          ┆ 27413             ┆ 615.285714         │
# │ 2026-02-10 ┆ Eco-Ally  ┆ 160          ┆ 11782             ┆ 292.571429         │
# │ 2026-02-10 ┆ Premium   ┆ 27           ┆ 3116              ┆ 129.0              │
# │ 2026-02-10 ┆ Basic     ┆ 924          ┆ 28337             ┆ 649.142857         │
# └────────────┴───────────┴──────────────┴───────────────────┴────────────────────┘

# %%
fig_rolling_avg = px.line(
    impact_over_time.to_pandas(),
    x='created_at',
    y='rolling_avg_impact',
    color='user_tier',
    title='7-Day Rolling Average Eco-Impact by User Tier',
    labels={'created_at':'Date','rolling_avg_impact':'7-Day Avg Impact','user_tier':'Tier'},
    template='plotly_white'
)

fig_rolling_avg.update_traces(line=dict(width=3))
fig_rolling_avg.update_layout(
    hovermode='x unified',
    yaxis_title='Eco-Score Impact (Rolling Average)',
    xaxis_title='Timeline'
)
fig_rolling_avg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f57c6759-8be3-4a04-af45-7dd0be352a7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f57c6759-8be3-4a04-af45-7dd0be352a7d")) {                    Plotly.newPlot(                        "f57c6759-8be3-4a04-af45-7dd0be352a7d",                        [{"hovertemplate":"Tier=Basic\u003cbr\u003eDate=%{x}\u003cbr\u003e7-Day Avg Impact=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic","line":{"color":"#636efa","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Basic","orientation":"v","showlegend":true,"x":["2026-01-01T00:00:00","2026-01-02T00:00:00","2026-01-03T00:00:00","2026-01-04T00:00:00","2026-01-05T00:00:00","2026-01-06T00:00:00","2026-01-07T00:00:00","2026-01-08T00:00:00","2026-01-09T00:00:00","2026-01-10T00:00:00","2026-01-11T00:00:00","2026-01-12T00:00:00","2026-01-13T00:00:00","2026-01-14T00:00:00","2026-01-15T00:00:00","2026-01-16T00:00:00","2026-01-17T00:00:00","2026-01-18T00:00:00","2026-01-19T00:00:00","2026-01-20T00:00:00","2026-01-21T00:00:00","2026-01-22T00:00:00","2026-01-23T00:00:00","2026-01-24T00:00:00","2026-01-25T00:00:00","2026-01-26T00:00:00","2026-01-27T00:00:00","2026-01-28T00:00:00","2026-01-29T00:00:00","2026-01-30T00:00:00","2026-01-31T00:00:00","2026-02-01T00:00:00","2026-02-02T00:00:00","2026-02-03T00:00:00","2026-02-04T00:00:00","2026-02-05T00:00:00","2026-02-06T00:00:00","2026-02-07T00:00:00","2026-02-08T00:00:00","2026-02-09T00:00:00","2026-02-10T00:00:00"],"xaxis":"x","y":[null,null,null,null,null,null,602.4285714285714,640.5714285714286,693.7142857142857,685.8571428571429,703.0,713.8571428571429,724.0,733.1428571428571,634.4285714285714,581.1428571428571,641.5714285714286,652.2857142857143,703.4285714285714,705.5714285714286,671.1428571428571,769.0,738.1428571428571,784.8571428571429,755.1428571428571,788.0,828.8571428571429,823.7142857142857,780.0,801.7142857142857,741.0,782.7142857142857,672.4285714285714,634.7142857142857,640.7142857142857,659.7142857142857,652.0,649.2857142857143,602.4285714285714,615.2857142857143,649.1428571428571],"yaxis":"y","type":"scatter"},{"hovertemplate":"Tier=Premium\u003cbr\u003eDate=%{x}\u003cbr\u003e7-Day Avg Impact=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Premium","line":{"color":"#EF553B","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Premium","orientation":"v","showlegend":true,"x":["2026-01-01T00:00:00","2026-01-03T00:00:00","2026-01-04T00:00:00","2026-01-05T00:00:00","2026-01-06T00:00:00","2026-01-09T00:00:00","2026-01-10T00:00:00","2026-01-11T00:00:00","2026-01-12T00:00:00","2026-01-13T00:00:00","2026-01-14T00:00:00","2026-01-15T00:00:00","2026-01-16T00:00:00","2026-01-17T00:00:00","2026-01-19T00:00:00","2026-01-20T00:00:00","2026-01-21T00:00:00","2026-01-22T00:00:00","2026-01-24T00:00:00","2026-01-26T00:00:00","2026-01-27T00:00:00","2026-01-28T00:00:00","2026-01-29T00:00:00","2026-01-30T00:00:00","2026-01-31T00:00:00","2026-02-01T00:00:00","2026-02-02T00:00:00","2026-02-05T00:00:00","2026-02-08T00:00:00","2026-02-10T00:00:00"],"xaxis":"x","y":[null,null,null,null,null,null,94.85714285714286,64.0,65.71428571428571,51.142857142857146,52.0,49.714285714285715,42.42857142857143,55.285714285714285,65.42857142857143,68.85714285714286,93.42857142857143,101.28571428571429,118.14285714285714,127.28571428571429,115.71428571428571,111.71428571428571,137.28571428571428,108.85714285714286,103.71428571428571,112.28571428571429,135.85714285714286,158.42857142857142,162.28571428571428,129.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Tier=Eco-Ally\u003cbr\u003eDate=%{x}\u003cbr\u003e7-Day Avg Impact=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eco-A ...

# %% [markdown]
# # **The Conversion Funnel**
# - How many users make if from *session_start* to c*omplete_listing* ?

# %%
# Force the events to use ONLY IDs that exist in df_users
valid_ids = df_users["user_id"].unique().to_list()

df_events = df_events.with_columns(
    pl.Series("user_id", [random.choice(valid_ids) for _ in range(len(df_events))])
)

# %%
# Enrich events with user data
df_enriched = df_events.join(df_users, on="user_id", how="left")

# %%
# Aggregate unique users per stage and tier
funnel_data = (
    df_enriched.group_by(['event_type','user_tier'])
    .agg(pl.col("user_id").n_unique().alias('unique_users'))
    .sort('unique_users',descending=True)
)

display(funnel_data)
# Out:
# shape: (12, 3)
# ┌──────────────────┬───────────┬──────────────┐
# │ event_type       ┆ user_tier ┆ unique_users │
# │ ---              ┆ ---       ┆ ---          │
# │ str              ┆ str       ┆ u32          │
# ╞══════════════════╪═══════════╪══════════════╡
# │ session_start    ┆ Basic     ┆ 324          │
# │ search_item      ┆ Basic     ┆ 324          │
# │ start_listing    ┆ Basic     ┆ 324          │
# │ complete_listing ┆ Basic     ┆ 311          │
# │ session_start    ┆ Eco-Ally  ┆ 139          │
# │ …                ┆ …         ┆ …            │
# │ complete_listing ┆ Eco-Ally  ┆ 134          │
# │ session_start    ┆ Premium   ┆ 37           │
# │ start_listing    ┆ Premium   ┆ 37           │
# │ search_item      ┆ Premium   ┆ 37           │
# │ complete_listing ┆ Premium   ┆ 36           │
# └──────────────────┴───────────┴──────────────┘

# %%
fig_funnel = px.funnel(
    funnel_data.to_pandas(),
    x='unique_users',
    y='event_type',
    color='user_tier',
    title='TerraLoop: Listing Funnel by Tier',
    labels={'unique_users':'Users','user_tier':'Tier'}
)

fig_funnel.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1a075afa-6b65-4e24-ab3a-2a68bb48b495" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a075afa-6b65-4e24-ab3a-2a68bb48b495")) {                    Plotly.newPlot(                        "1a075afa-6b65-4e24-ab3a-2a68bb48b495",                        [{"hovertemplate":"Tier=Basic\u003cbr\u003eUsers=%{x}\u003cbr\u003eevent_type=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic","marker":{"color":"#636efa"},"name":"Basic","orientation":"v","showlegend":true,"x":[324,324,324,311],"xaxis":"x","y":["session_start","search_item","start_listing","complete_listing"],"yaxis":"y","type":"funnel"},{"hovertemplate":"Tier=Eco-Ally\u003cbr\u003eUsers=%{x}\u003cbr\u003eevent_type=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eco-Ally","marker":{"color":"#EF553B"},"name":"Eco-Ally","orientation":"v","showlegend":true,"x":[139,139,139,134],"xaxis":"x","y":["session_start","start_listing","search_item","complete_listing"],"yaxis":"y","type":"funnel"},{"hovertemplate":"Tier=Premium\u003cbr\u003eUsers=%{x}\u003cbr\u003eevent_type=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Premium","marker":{"color":"#00cc96"},"name":"Premium","orientation":"v","showlegend":true,"x":[37,37,37,36],"xaxis":"x","y":["session_start","start_listing","search_item","complete_listing"],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666 ...

# %% [markdown]
# # **Stickiness Ration (DAU/MAU)**
# - How many users come back daily vs. monthly ?

# %%
# Convert timestamp to a date
# Only convert if 'event_time' is not already a date type
if df_enriched['event_time'].dtype != pl.Date:
    df_enriched = df_enriched.with_columns(pl.col('event_time').str.to_datetime("%Y-%m-%dT%H:%M:%S%.f").cast(pl.Date).alias('date'))
else:
    df_enriched = df_enriched.with_columns(pl.col('event_time').alias('date'))

# %%
dau = df_enriched.group_by("date").agg(pl.col('user_id').n_unique().alias('dau'))
mau = df_enriched.select(pl.col("user_id").n_unique()).item() # Total unique users in the month

stickiness = (dau.select(pl.col('dau').mean()).item() / mau) * 100
print(f'App Stickiness: {stickiness:.1f}%')
# Out:
# App Stickiness: 52.9%

# %% [markdown]
# # **Event Category Affinity**
# - This tells us if Pro users are more interested in Industrial categories while Basic users stick to Clothing/Electronics

# %%
# 1. Clean the keys for the join
df_events = df_events.with_columns(pl.col("user_id").str.strip_chars().str.to_uppercase())
df_users = df_users.with_columns(pl.col("user_id").str.strip_chars().str.to_uppercase())

# 2. Join events with users
# This ensures every event row now has 'item_category' AND 'user_tier'
df_enriched = df_events.join(df_users, on="user_id", how="left")

# 3. Verify the columns are there
print("Columns in enriched events:", df_enriched.columns)
# Out:
# Columns in enriched events: ['user_id', 'event_type', 'event_time', 'platform', 'session_id', 'item_category', 'signup_date', 'user_tier', 'region']

# %%
# Aggregate unique users per category and tier
affinity_data = (
    df_enriched.group_by(["item_category", "user_tier"])
    .agg(pl.col("user_id").n_unique().alias("unique_users"))
    .sort("unique_users", descending=True)
)

display(affinity_data.head())
# Out:
# shape: (5, 3)
# ┌─────────────────┬───────────┬──────────────┐
# │ item_category   ┆ user_tier ┆ unique_users │
# │ ---             ┆ ---       ┆ ---          │
# │ str             ┆ str       ┆ u32          │
# ╞═════════════════╪═══════════╪══════════════╡
# │ Phone           ┆ Basic     ┆ 324          │
# │ Laptop          ┆ Basic     ┆ 324          │
# │ Battery         ┆ Basic     ┆ 324          │
# │ Small Appliance ┆ Basic     ┆ 324          │
# │ Laptop          ┆ Eco-Ally  ┆ 139          │
# └─────────────────┴───────────┴──────────────┘

# %%
fig_affinity = px.parallel_categories(
    affinity_data.to_pandas(),
    dimensions=['user_tier', 'item_category'],
    title="<b>User Interest: Tier to Category Mapping</b>",
    color="unique_users",
    color_continuous_scale="Tealgrn"
)
fig_affinity.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1fbb85c9-f53e-4ab6-92d6-4de4574b694e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fbb85c9-f53e-4ab6-92d6-4de4574b694e")) {                    Plotly.newPlot(                        "1fbb85c9-f53e-4ab6-92d6-4de4574b694e",                        [{"dimensions":[{"label":"user_tier","values":["Basic","Basic","Basic","Basic","Eco-Ally","Eco-Ally","Eco-Ally","Eco-Ally","Premium","Premium","Premium","Premium"]},{"label":"item_category","values":["Phone","Laptop","Battery","Small Appliance","Laptop","Phone","Battery","Small Appliance","Laptop","Phone","Battery","Small Appliance"]}],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"line":{"color":[324,324,324,324,139,139,139,139,37,37,37,37],"coloraxis":"coloraxis"},"name":"","type":"parcats"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size": ...

# %% [markdown]
# # **Category Conversion "Stickers"**
#
# - Which category has the **highest completion rate.**

# %%
# 1. Calculate Start vs Complete per category
cat_conversion = (
    df_enriched.group_by(["item_category"])
    .agg([
        pl.col("event_type").filter(pl.col("event_type") == "start_listing").count().alias("starts"),
        pl.col("event_type").filter(pl.col("event_type") == "complete_listing").count().alias("completes")
    ])
    .with_columns(
        (pl.col("completes") / pl.col("starts")).alias("conversion_rate")
    )
    .sort("conversion_rate", descending=True)
)

display(cat_conversion)
# Out:
# shape: (4, 4)
# ┌─────────────────┬────────┬───────────┬─────────────────┐
# │ item_category   ┆ starts ┆ completes ┆ conversion_rate │
# │ ---             ┆ ---    ┆ ---       ┆ ---             │
# │ str             ┆ u32    ┆ u32       ┆ f64             │
# ╞═════════════════╪════════╪═══════════╪═════════════════╡
# │ Small Appliance ┆ 1010   ┆ 395       ┆ 0.391089        │
# │ Battery         ┆ 1043   ┆ 383       ┆ 0.36721         │
# │ Phone           ┆ 981    ┆ 353       ┆ 0.359837        │
# │ Laptop          ┆ 1017   ┆ 352       ┆ 0.346116        │
# └─────────────────┴────────┴───────────┴─────────────────┘

# %%
fig_cat_conv = px.bar(
    cat_conversion.to_pandas(),
    x="conversion_rate",
    y="item_category",
    orientation='h',
    title="<b>Listing Completion Rate by Category</b>",
    color="conversion_rate",
    text_auto='.1%', # Shows the percentage on the bar
    color_continuous_scale="RdYlGn"
)
fig_cat_conv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fa5b0db4-a13c-494c-b63a-b06d831f0bc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa5b0db4-a13c-494c-b63a-b06d831f0bc1")) {                    Plotly.newPlot(                        "fa5b0db4-a13c-494c-b63a-b06d831f0bc1",                        [{"alignmentgroup":"True","hovertemplate":"conversion_rate=%{marker.color}\u003cbr\u003eitem_category=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.3910891089108911,0.36720997123681687,0.3598369011213048,0.34611602753195675],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","texttemplate":"%{x:.1%}","x":[0.3910891089108911,0.36720997123681687,0.3598369011213048,0.34611602753195675],"xaxis":"x","y":["Small Appliance","Battery","Phone","Laptop"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"co ...

# %% [markdown]
# # **Category Dominance (Sunburst Chart)**

# %%
sunburst_data = (
    df_listings_enriched.group_by(["region", "item_category", "user_tier"])
    .agg(pl.col("listing_id").count().alias("count"))
    .filter(pl.col('item_category').is_not_null()) # Filter out rows where item_category is null
)

display(sunburst_data)
# Out:
# shape: (5, 4)
# ┌───────────────┬─────────────────┬───────────┬───────┐
# │ region        ┆ item_category   ┆ user_tier ┆ count │
# │ ---           ┆ ---             ┆ ---       ┆ ---   │
# │ str           ┆ str             ┆ str       ┆ u32   │
# ╞═══════════════╪═════════════════╪═══════════╪═══════╡
# │ Europe        ┆ Laptop          ┆ Eco-Ally  ┆ 2     │
# │ Asia          ┆ Laptop          ┆ Basic     ┆ 2     │
# │ North America ┆ Phone           ┆ Basic     ┆ 2     │
# │ Asia          ┆ Laptop          ┆ Eco-Ally  ┆ 1     │
# │ North America ┆ Small Appliance ┆ Eco-Ally  ┆ 1     │
# └───────────────┴─────────────────┴───────────┴───────┘

# %%
fig_sun = px.sunburst(
    sunburst_data.to_pandas(),
    path=['region', 'item_category', 'user_tier'],
    values='count',
    title="<b>TerraLoop Ecosystem: Where is the Waste Coming From?</b>",
    color='count',
    color_continuous_scale='RdYlGn' # Red to Green for Eco-Impact
)
fig_sun.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="22488bda-aa91-4c56-a2b5-a750abf4cb87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22488bda-aa91-4c56-a2b5-a750abf4cb87")) {                    Plotly.newPlot(                        "22488bda-aa91-4c56-a2b5-a750abf4cb87",                        [{"branchvalues":"total","customdata":[[2],[1],[2],[2],[1],["(?)"],[2],[2],[1],["(?)"],[2],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003ecount=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Europe\u002fLaptop\u002fEco-Ally","North America\u002fSmall Appliance\u002fEco-Ally","Asia\u002fLaptop\u002fBasic","North America\u002fPhone\u002fBasic","Asia\u002fLaptop\u002fEco-Ally","Asia\u002fLaptop","Europe\u002fLaptop","North America\u002fPhone","North America\u002fSmall Appliance","Asia","Europe","North America"],"labels":["Eco-Ally","Eco-Ally","Basic","Basic","Eco-Ally","Laptop","Laptop","Phone","Small Appliance","Asia","Europe","North America"],"marker":{"colors":["#636efa","#EF553B","#636efa","#636efa","#EF553B","#00cc96","#636efa","#636efa","#EF553B","#00cc96","#636efa","#00cc96"]},"name":"","parents":["Europe\u002fLaptop","North America\u002fSmall Appliance","Asia\u002fLaptop","North America\u002fPhone","Asia\u002fLaptop","Asia","Europe","North America","North America","","",""],"values":[2,1,2,2,1,3,2,2,1,3,2,3],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"], ...

# %% [markdown]
# # **Listing Lead Time**
# - How many days pass between when a user joins and when they post their first listing?

# %%
activation_df = (
    df_listings_enriched.with_columns([
        pl.col("created_at").str.to_datetime("%Y-%m-%dT%H:%M:%S%.f").cast(pl.Date),
        pl.col("signup_date").str.to_datetime("%Y-%m-%dT%H:%M:%S%.f").cast(pl.Date)
    ])
    .with_columns(
        (pl.col("created_at") - pl.col("signup_date")).dt.total_days().alias("days_to_list")
    )
)

display(activation_df.head())
# Out:
# shape: (5, 9)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ listing_i ┆ owner_id ┆ eco_score ┆ status    ┆ … ┆ signup_da ┆ user_tier ┆ region    ┆ days_to_l │
# │ d         ┆ ---      ┆ _impact   ┆ ---       ┆   ┆ te        ┆ ---       ┆ ---       ┆ ist       │
# │ ---       ┆ str      ┆ ---       ┆ str       ┆   ┆ ---       ┆ str       ┆ str       ┆ ---       │
# │ str       ┆          ┆ i64       ┆           ┆   ┆ date      ┆           ┆           ┆ i64       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ LST-00000 ┆ TL0200   ┆ 32        ┆ cancelled ┆ … ┆ 2026-01-3 ┆ Basic     ┆ North     ┆ -5        │
# │           ┆          ┆           ┆           ┆   ┆ 1         ┆           ┆ America   ┆           │
# │ LST-00001 ┆ TL0337   ┆ 53        ┆ completed ┆ … ┆ 2026-01-2 ┆ Basic     ┆ Europe    ┆ 7         │
# │           ┆          ┆           ┆           ┆   ┆ 0         ┆           ┆           ┆           │
# │ LST-00002 ┆ TL0129   ┆ 18        ┆ completed ┆ … ┆ 2026-01-0 ┆ Eco-Ally  ┆ North     ┆ 0         │
# │           ┆          ┆           ┆           ┆   ┆ 6         ┆           ┆ America   ┆           │
# │ LST-00003 ┆ TL0197   ┆ 100       ┆ active    ┆ … ┆ 2026-01-1 ┆ Eco-Ally  ┆ Asia      ┆ 8         │
# │           ┆          ┆           ┆           ┆   ┆ 8         ┆           ┆           ┆           │
# │ LST-00004 ┆ TL0357   ┆ 37        ┆ cancelled ┆ … ┆ 2026-01-3 ┆ Basic     ┆ Asia      ┆ -4        │
# │           ┆          ┆           ┆           ┆   ┆ 1         ┆           ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
fig_dist = px.histogram(
    activation_df.to_pandas(),
    x="days_to_list",
    color="user_tier",
    marginal="box", # Adds a box plot on top
    title="<b>Days to First Listing: User Activation Speed</b>",
    labels={"days_to_list": "Days from Signup to Listing"}
)
fig_dist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c2c29bf4-de74-4d8e-af93-98da1ed21fd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2c29bf4-de74-4d8e-af93-98da1ed21fd4")) {                    Plotly.newPlot(                        "c2c29bf4-de74-4d8e-af93-98da1ed21fd4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"user_tier=Basic\u003cbr\u003eDays from Signup to Listing=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Basic","offsetgroup":"Basic","orientation":"v","showlegend":true,"x":[-5,7,-4,0,9,-5,20,-1,9,9,18,24,0,6,-9,10,-4,6,-3,-2,9,25,-12,10,-26,11,-7,-7,25,13,-7,-26,15,-16,-2,6,-3,-12,-8,7,7,-18,16,-16,-23,-5,9,0,-2,2,17,23,26,6,-3,10,-19,0,-18,22,32,1,-10,9,3,-17,23,13,-14,9,20,-4,-1,20,30,11,-2,-13,16,8,-3,-8,27,-19,1,21,9,2,-3,-20,-5,21,-9,14,5,0,4,-10,7,39,-22,26,12,32,6,16,14,-7,-11,6,18,24,9,-1,11,-4,22,-6,-7,-14,12,23,4,2,17,-2,9,-3,1,-1,0,-11,35,10,20,12,2,-13,-18,6,27,18,1,7,4,-2,4,-18,-20,-13,4,39,-11,-12,24,-16,19,14,-6,7,19,-26,-8,-19,-1,-13,1,-17,34,-19,7,-20,-20,10,-5,10,-14,36,13,2,-4,-9,-14,2,-9,6,-2,-6,-5,4,-25,20,7,-9,16,7,20,-6,-13,6,-4,12,-1,5,4,6,28,4,12,31,35,-30,10,-19,23,-9,23,15,1,6,20,13,3,6,-15,1,3,16,22,-9,6,-2,15,22,17,4,13,10,-10,17,-5,-15,12,3,-13,7,37,-5,28,-4,1,13,39,-15,-7,-20,-8,-10,4,-19,2,17,23,-10,10,9,-20,15,3,17,-11,26,20,4,7,-15,18,-21,-22,-15,-29,15,7,3,28,3,-8,12,-8,18,8,10,-4,-25,18,10,-1,1,16,3,14,-1,-11,25,34,30,23,20,14,1,-12,28,12,-11,15,2,33,21,13,13,34,-2,-11,5,2,-11,13,15,22,-10,24,12,-17,-9,-4,14,28,-14,13,-1,-7,2,21,5,-24,16,35,-13,12,34,6,-7,-8,28,-5,-6,5,5,-1,8,6,-9,4,-15,17,8,31,39,23,24,31,16,29,26,7,-19,21,2,2,8,17,-22,31,-7,7,-22,19,20,14,22,25,6,14,-3,7,3,-19,-4,7,18,1,15,-7,15,-6,-9,-5,-7,-9,-13,5,14,-1,7,-27,-12,-1,4,1,-10,-6,-3,1,23,23,-6,-17,10,6,22,-5,-6,17,-8,28,-2,8,-18,7,31,-23,29,-22,8,18,18,26,9,18,-15,13,2,21,27,-26,4,-13,-1,-27,-2,-14,22,18,8,-16,-2,14,-11,-19,-14,5,19,-1,17,7,16,-8,28,9,-23,3,-7,-19,17,0,4,-16,0,-17,17,11,17,4,-10,29,-27,-2,5,28,39,-2,-17,-11,27,25,15,-19,8,-7,-11,18,21,30],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"user_tier=Basic\u003cbr\u003eDays from Signup to Listing=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basic","marker":{"color":"#636efa"},"name":"Basic","notched":true,"offsetgroup":"Basic","showlegend":false,"x":[-5,7,-4,0,9,-5,20,-1,9,9,18,24,0,6,-9,10,-4,6,-3,-2,9,25,-12,10,-26,11,-7,-7,25,13,-7,-26,15,-16,-2,6,-3,-12,-8,7,7,-18,16,-16,-23,-5,9,0,-2,2,17,23,26,6,-3,10,-19,0,-18,22,32,1,-10,9,3,-17,23,13,-14,9,20,-4,-1,20,30,11,-2,-13,16,8,-3,-8,27,-19,1,21,9,2,-3,-20,-5,21,-9,14,5,0,4,-10,7,39,-22,26,12,32,6,16,14,-7,-11,6,18,24,9,-1,11,-4,22,-6,-7,-14,12,23,4,2,17,-2,9,-3,1,-1,0,-11,35,10,20,12,2,-13,-18,6,27,18,1,7,4,-2,4,-18,-20,-13,4,39,-11,-12,24,-16,19,14,-6,7,19,-26,-8,-19,-1,-13,1,-17,34,-19,7,-20,-20,10,-5,10,-14,36,13,2,-4,-9,-14,2,-9,6,-2,-6,-5,4,-25,20,7,-9,16,7,20,-6,-13,6,-4,12,-1,5,4,6,28,4,12,31,35,-30,10,-19,23,-9,23,15,1,6,20,13,3,6,-15,1,3,16,22,-9,6,-2,15,22,17,4,13,10,-10,17,-5,-15,12,3,-13,7,37,-5,28,-4,1,13,39,-15,-7,-20,-8,-10,4,-19,2,17,23,-10,10,9,-20,15,3,17,-11,26,20,4,7,-15,18,-21,-22,-15,-29,15,7,3,28,3,-8,12,-8,18,8,10,-4,-25,18,10,-1,1,16,3,14,-1,-11,25,34,30,23,20,14,1,-12,28,12,-11,15,2,33,21,13,13,34,-2,-11,5,2,-11,13,15,22,-10,24,12,-17,-9,-4,14,28,-14,13,-1,-7,2,21,5,-24,16,35,-13,12,34,6,-7,-8,28,-5,-6,5,5,-1,8,6,-9,4,-15,17,8,31,39,23,24,31,16,29,26,7,-19,21,2,2,8,17,-22,31,-7,7,-22,19,20,14,22,25,6,14,-3,7,3,-19,-4,7,18,1,15,-7,15,-6,-9,-5,-7,-9,-13,5,14,-1,7,-27,-12,-1,4,1,-10,-6,-3,1,23,23,-6,-17,10,6,22,-5,-6,17,-8 ...
